# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DataSet 19

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\19.csv")
a
# Out:
#      index     SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 0     1932  EAST RAJASTHAN  1901  21.6   8.9   2.9   0.7   5.0   15.0  164.8
# 1     1933  EAST RAJASTHAN  1902   4.1   0.7   0.0   1.8   9.9   34.6  247.6
# 2     1934  EAST RAJASTHAN  1903   1.9   0.7   1.3   0.1  12.9   15.6  238.2
# 3     1935  EAST RAJASTHAN  1904   4.3   5.5  21.7   0.2  27.5   49.9  289.7
# 4     1936  EAST RAJASTHAN  1905   4.1   8.8   3.2   1.6   2.0   14.4  130.5
# ..     ...             ...   ...   ...   ...   ...   ...   ...    ...    ...
# 110   2042  EAST RAJASTHAN  2011   0.0  11.2   0.2   0.5   5.1  140.9  193.6
# 111   2043  EAST RAJASTHAN  2012   1.9   0.0   0.0   3.6   9.5   11.2  170.5
# 112   2044  EAST RAJASTHAN  2013   1.4  21.7   0.4   3.2   1.0   90.6  319.0
# 113   2045  EAST RAJASTHAN  2014  28.4  10.0   6.4   7.3   8.4   23.5  197.1
# 114   2046  EAST RAJASTHAN  2015  12.1   0.1  55.9  15.9   3.5   96.4  297.6
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a.plot.pie(y='JUN',figsize=(6.5,6.5),labels=None,legend=None)
# Out:
# <AxesSubplot:ylabel='JUN'>

# %% [markdown]
# # DataSet 20

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\20.csv")
a
# Out:
#      index     SUBDIVISION  YEAR  JAN   FEB   MAR   APR   MAY   JUN    JUL  \
# 0     1817  WEST RAJASTHAN  1901  6.7   0.0   1.1   0.0   6.1   3.0   79.0
# 1     1818  WEST RAJASTHAN  1902  0.0   0.0   0.0   0.5   4.0  49.1   27.0
# 2     1819  WEST RAJASTHAN  1903  1.7   1.3   5.5   0.0   4.2   2.7  154.8
# 3     1820  WEST RAJASTHAN  1904  3.8   2.9  16.3   0.7  11.4  14.6   39.8
# 4     1821  WEST RAJASTHAN  1905  6.3   4.8   0.7   1.3   0.3   4.9   30.1
# ..     ...             ...   ...  ...   ...   ...   ...   ...   ...    ...
# 110   1927  WEST RAJASTHAN  2011  0.0  11.8   1.5   1.5   7.8  24.4   88.5
# 111   1928  WEST RAJASTHAN  2012  0.5   0.0   0.0   9.5  10.4   5.3   40.4
# 112   1929  WEST RAJASTHAN  2013  8.6  21.8   4.2   3.1   1.7  37.6  104.5
# 113   1930  WEST RAJASTHAN  2014  0.8   2.2   4.7   8.4  23.0  13.8   94.3
# 114   1931  WEST RAJASTHAN  2015  1.4   0.9  30.3  25.2  15.5  53.2  234.6
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.scatter(y='APR',x='OCT',legend=None)
# Out:
# <AxesSubplot:xlabel='OCT', ylabel='APR'>

# %%
a.plot.pie(y='NOV',legend=None,labels=None,figsize=(6.5,6.5),)
# Out:
# <AxesSubplot:ylabel='NOV'>

# %% [markdown]
# # DataSet 21

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\21.csv")
a
# Out:
#      index      SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN  \
# 0     1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4
# 1     1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3
# 2     1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9
# 3     1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9
# 4     1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3
# ..     ...              ...   ...    ...    ...    ...    ...    ...    ...
# 110   1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5
# 111   1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6
# 112   1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5
# 113   1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3
# 114   1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          114 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          114 non-null    float64
#  14  DEC          114 non-null    float64
#  15  ANNUAL       114 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b=a.fillna(method="ffill")
b
# Out:
#      index      SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN  \
# 0     1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4
# 1     1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3
# 2     1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9
# 3     1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9
# 4     1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3
# ..     ...              ...   ...    ...    ...    ...    ...    ...    ...
# 110   1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5
# 111   1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6
# 112   1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5
# 113   1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3
# 114   1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4
#
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
b.plot.pie(y='AUG',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='AUG'>

# %% [markdown]
# # DataSet 22

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\22.csv")
a
# Out:
#      index       SUBDIVISION  YEAR    JAN    FEB    MAR   APR   MAY    JUN  \
# 0     1587  HIMACHAL PRADESH  1901  137.8  174.5   75.0  19.2  89.6   32.7
# 1     1588  HIMACHAL PRADESH  1902    6.5   27.0  104.4  76.2  61.3   78.8
# 2     1589  HIMACHAL PRADESH  1903   76.5   21.4  213.7  25.4  54.7   32.2
# 3     1590  HIMACHAL PRADESH  1904   79.3   22.4  131.7  48.0  90.3   33.1
# 4     1591  HIMACHAL PRADESH  1905   81.3   76.8  160.2  39.3  50.4   43.6
# ..     ...               ...   ...    ...    ...    ...   ...   ...    ...
# 110   1697  HIMACHAL PRADESH  2011   43.9   97.4   49.7  62.4  45.1  118.3
# 111   1698  HIMACHAL PRADESH  2012   92.3   51.3   28.4  55.9   9.4   31.1
# 112   1699  HIMACHAL PRADESH  2013   79.9  182.6   76.6  28.9  32.6  233.6
# 113   1700  HIMACHAL PRADESH  2014   69.6  124.9  125.2  60.6  68.9   51.7
# 114   1701  HIMACHAL PRADESH  2015   67.2  156.6  192.5  84.9  45.0   85.8
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.pie(y='YEAR',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='YEAR'>

# %% [markdown]
# # DataSet 23

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\23.csv")
a
# Out:
#      index                 SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY  \
# 0     1357  HARYANA DELHI & CHANDIGARH  1901  35.4  28.9  11.1   0.0   5.1
# 1     1358  HARYANA DELHI & CHANDIGARH  1902   0.0   0.7   2.9  10.2  15.8
# 2     1359  HARYANA DELHI & CHANDIGARH  1903  14.7   0.5   2.3   0.5   8.5
# 3     1360  HARYANA DELHI & CHANDIGARH  1904   7.6   0.7  48.0   0.5  29.3
# 4     1361  HARYANA DELHI & CHANDIGARH  1905  44.8  20.8  14.0   1.3   7.4
# ..     ...                         ...   ...   ...   ...   ...   ...   ...
# 110   1467  HARYANA DELHI & CHANDIGARH  2011   0.7  26.7   6.9   8.9  28.7
# 111   1468  HARYANA DELHI & CHANDIGARH  2012   8.2   0.2   0.1  11.8   3.8
# 112   1469  HARYANA DELHI & CHANDIGARH  2013  21.1  52.2   5.3   3.3   1.4
# 113   1470  HARYANA DELHI & CHANDIGARH  2014  13.0  17.3  26.8   7.5  20.3
# 114   1471  HARYANA DELHI & CHANDIGARH  2015  12.4   6.6  71.8  34.8   8.4
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.scatter(y='JAN',x='DEC',legend=None)
# Out:
# <AxesSubplot:xlabel='DEC', ylabel='JAN'>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.pie(y='JUL',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='JUL'>

# %%
a.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # DataSet 24

# %%
b=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\24.csv")
b
# Out:
#      index SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 0     1472      PUNJAB  1901  55.7  50.1  25.2   2.1  25.2   10.4  178.2
# 1     1473      PUNJAB  1902   0.0   0.8   9.9  10.9  29.6   49.9  125.6
# 2     1474      PUNJAB  1903  29.5   0.5  45.0   1.3   9.2    5.2  212.2
# 3     1475      PUNJAB  1904  24.2   1.7  87.8   1.2  13.8   22.0   59.9
# 4     1476      PUNJAB  1905  53.0  40.3  24.3   0.5   2.2   19.2  122.6
# ..     ...         ...   ...   ...   ...   ...   ...   ...    ...    ...
# 110   1582      PUNJAB  2011   3.5  35.6   8.2  17.8  18.9  162.9  120.9
# 111   1583      PUNJAB  2012  62.6   3.2   1.9  31.1   1.6   11.9  120.2
# 112   1584      PUNJAB  2013   9.3  50.1  11.6   3.4   3.6  120.3  117.9
# 113   1585      PUNJAB  2014  21.8  20.1  30.3  24.5  20.8   20.6   76.3
# 114   1586      PUNJAB  2015  17.7  31.3  68.5  29.8  16.7   48.3  130.2
#
#        AUG    SEP   OCT  NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.pie(y='SEP',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='SEP'>
