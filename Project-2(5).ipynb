# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DataSet 25

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\25.csv")
a
# Out:
#      index         SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN  \
# 0     1127  WEST UTTAR PRADESH  1901  51.4  25.6   9.5   0.7   5.6   23.8
# 1     1128  WEST UTTAR PRADESH  1902   4.6   4.6   0.6   4.8   7.2   54.5
# 2     1129  WEST UTTAR PRADESH  1903  13.4   0.4   1.2   0.0   8.2   32.7
# 3     1130  WEST UTTAR PRADESH  1904   6.3   2.0  29.7   0.4  24.8   68.5
# 4     1131  WEST UTTAR PRADESH  1905  32.3  26.6  14.8   3.6   7.1   18.9
# ..     ...                 ...   ...   ...   ...   ...   ...   ...    ...
# 110   1237  WEST UTTAR PRADESH  2011   2.1  10.4   3.9   2.8  29.6  175.9
# 111   1238  WEST UTTAR PRADESH  2012  14.5   0.1   1.4   4.7   0.3    4.0
# 112   1239  WEST UTTAR PRADESH  2013  20.4  69.5   3.5   1.6   2.1  190.6
# 113   1240  WEST UTTAR PRADESH  2014  48.3  29.4  22.6   5.3  11.0   22.0
# 114   1241  WEST UTTAR PRADESH  2015  31.6   7.2  66.8  21.0   8.1   72.0
#
#        JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a.plot.pie(y='OCT',figsize=(6.5,6.5),labels=None,legend=None)
# Out:
# <AxesSubplot:ylabel='OCT'>

# %% [markdown]
# # DataSet 26

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\26.csv")
a
# Out:
#      index                SUBDIVISION  YEAR    JAN    FEB    MAR    APR  \
# 0        0  ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3
# 1        1  ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0
# 2        2  ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0
# 3        3  ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4
# 4        4  ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9
# ..     ...                        ...   ...    ...    ...    ...    ...
# 105    105  ANDAMAN & NICOBAR ISLANDS  2011  265.9   84.8  272.8  111.4
# 106    106  ANDAMAN & NICOBAR ISLANDS  2012  119.9   45.6   30.9   55.8
# 107    107  ANDAMAN & NICOBAR ISLANDS  2013   67.1   37.6   43.0   46.3
# 108    108  ANDAMAN & NICOBAR ISLANDS  2014   41.9    8.6    0.0   11.1
# 109    109  ANDAMAN & NICOBAR ISLANDS  2015  126.8    7.6    3.1  138.2
#
#        MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        110 non-null    int64
#  1   SUBDIVISION  110 non-null    object
#  2   YEAR         110 non-null    int64
#  3   JAN          110 non-null    float64
#  4   FEB          110 non-null    float64
#  5   MAR          108 non-null    float64
#  6   APR          108 non-null    float64
#  7   MAY          109 non-null    float64
#  8   JUN          108 non-null    float64
#  9   JUL          108 non-null    float64
#  10  AUG          108 non-null    float64
#  11  SEP          107 non-null    float64
#  12  OCT          108 non-null    float64
#  13  NOV          108 non-null    float64
#  14  DEC          107 non-null    float64
#  15  ANNUAL       104 non-null    float64
#  16  Jan-Feb      110 non-null    float64
#  17  Mar-May      107 non-null    float64
# ...

# %%
b=a.fillna(method="ffill")
b
# Out:
#      index                SUBDIVISION  YEAR    JAN    FEB    MAR    APR  \
# 0        0  ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3
# 1        1  ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0
# 2        2  ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0
# 3        3  ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4
# 4        4  ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9
# ..     ...                        ...   ...    ...    ...    ...    ...
# 105    105  ANDAMAN & NICOBAR ISLANDS  2011  265.9   84.8  272.8  111.4
# 106    106  ANDAMAN & NICOBAR ISLANDS  2012  119.9   45.6   30.9   55.8
# 107    107  ANDAMAN & NICOBAR ISLANDS  2013   67.1   37.6   43.0   46.3
# 108    108  ANDAMAN & NICOBAR ISLANDS  2014   41.9    8.6    0.0   11.1
# 109    109  ANDAMAN & NICOBAR ISLANDS  2015  126.8    7.6    3.1  138.2
#
#        MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        110 non-null    int64
#  1   SUBDIVISION  110 non-null    object
#  2   YEAR         110 non-null    int64
#  3   JAN          110 non-null    float64
#  4   FEB          110 non-null    float64
#  5   MAR          110 non-null    float64
#  6   APR          110 non-null    float64
#  7   MAY          110 non-null    float64
#  8   JUN          110 non-null    float64
#  9   JUL          110 non-null    float64
#  10  AUG          110 non-null    float64
#  11  SEP          110 non-null    float64
#  12  OCT          110 non-null    float64
#  13  NOV          110 non-null    float64
#  14  DEC          110 non-null    float64
#  15  ANNUAL       110 non-null    float64
#  16  Jan-Feb      110 non-null    float64
#  17  Mar-May      110 non-null    float64
# ...

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.scatter(y='APR',x='OCT',legend=None)
# Out:
# <AxesSubplot:xlabel='OCT', ylabel='APR'>

# %%
b.plot.pie(y='OCT',legend=None,labels=None,figsize=(6.5,6.5),)
# Out:
# <AxesSubplot:ylabel='OCT'>

# %% [markdown]
# # DataSet 27

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\27.csv")
a
# Out:
#     index        SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 0     110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 1     111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9   823.8
# 2     112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 3     113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 4     114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6
# ..    ...                ...   ...   ...    ...    ...    ...    ...     ...
# 92    202  ARUNACHAL PRADESH  2011  40.0   51.3  174.5  240.8  219.6   288.4
# 93    203  ARUNACHAL PRADESH  2012  57.8   35.8  134.2  403.4  187.4   645.8
# 94    204  ARUNACHAL PRADESH  2013  18.5   40.5  115.1  175.1  335.8   290.0
# 95    205  ARUNACHAL PRADESH  2014  19.0  101.9   80.3   86.7  299.0   415.8
# 96    206  ARUNACHAL PRADESH  2015  30.8   47.5   97.5  287.1  238.9   637.9
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        97 non-null     int64
#  1   SUBDIVISION  97 non-null     object
#  2   YEAR         97 non-null     int64
#  3   JAN          96 non-null     float64
#  4   FEB          96 non-null     float64
#  5   MAR          95 non-null     float64
#  6   APR          97 non-null     float64
#  7   MAY          97 non-null     float64
#  8   JUN          96 non-null     float64
#  9   JUL          96 non-null     float64
#  10  AUG          97 non-null     float64
#  11  SEP          97 non-null     float64
#  12  OCT          95 non-null     float64
#  13  NOV          95 non-null     float64
#  14  DEC          95 non-null     float64
#  15  ANNUAL       91 non-null     float64
#  16  Jan-Feb      96 non-null     float64
#  17  Mar-May      95 non-null     float64
# ...

# %%
b=a.fillna(method="ffill")
b
# Out:
#     index        SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 0     110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 1     111  ARUNACHAL PRADESH  1917  21.4  164.5   71.1  269.6  107.9   823.8
# 2     112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 3     113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 4     114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6
# ..    ...                ...   ...   ...    ...    ...    ...    ...     ...
# 92    202  ARUNACHAL PRADESH  2011  40.0   51.3  174.5  240.8  219.6   288.4
# 93    203  ARUNACHAL PRADESH  2012  57.8   35.8  134.2  403.4  187.4   645.8
# 94    204  ARUNACHAL PRADESH  2013  18.5   40.5  115.1  175.1  335.8   290.0
# 95    205  ARUNACHAL PRADESH  2014  19.0  101.9   80.3   86.7  299.0   415.8
# 96    206  ARUNACHAL PRADESH  2015  30.8   47.5   97.5  287.1  238.9   637.9
#
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        97 non-null     int64
#  1   SUBDIVISION  97 non-null     object
#  2   YEAR         97 non-null     int64
#  3   JAN          97 non-null     float64
#  4   FEB          97 non-null     float64
#  5   MAR          97 non-null     float64
#  6   APR          97 non-null     float64
#  7   MAY          97 non-null     float64
#  8   JUN          97 non-null     float64
#  9   JUL          96 non-null     float64
#  10  AUG          97 non-null     float64
#  11  SEP          97 non-null     float64
#  12  OCT          96 non-null     float64
#  13  NOV          96 non-null     float64
#  14  DEC          96 non-null     float64
#  15  ANNUAL       95 non-null     float64
#  16  Jan-Feb      97 non-null     float64
#  17  Mar-May      97 non-null     float64
# ...

# %%
b.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
b.plot.pie(y='MAR',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='MAR'>

# %% [markdown]
# # DataSet 28

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\28.csv")
a
# Out:
#      index        SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0      207  ASSAM & MEGHALAYA  1901  27.1  19.5   30.6  223.0  207.0  524.9
# 1      208  ASSAM & MEGHALAYA  1902   9.3  10.2  105.6  350.0  262.1  620.7
# 2      209  ASSAM & MEGHALAYA  1903  19.9  25.4  103.6  140.6  206.6  607.4
# 3      210  ASSAM & MEGHALAYA  1904  11.1  56.1   51.9  457.1  375.2  385.7
# 4      211  ASSAM & MEGHALAYA  1905  19.9  16.9  137.9  213.0  275.5  521.7
# ..     ...                ...   ...   ...   ...    ...    ...    ...    ...
# 110    317  ASSAM & MEGHALAYA  2011  11.1  11.4  109.0   92.1  238.3  316.0
# 111    318  ASSAM & MEGHALAYA  2012  15.2   6.9   28.8  279.1  185.8  729.7
# 112    319  ASSAM & MEGHALAYA  2013   1.1   9.6   44.0  112.8  346.7  286.2
# 113    320  ASSAM & MEGHALAYA  2014   2.0  28.3   29.3   51.5  351.1  426.4
# 114    321  ASSAM & MEGHALAYA  2015  13.4  15.5   37.5  250.9  332.5  558.5
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.pie(y='AUG',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='AUG'>

# %% [markdown]
# # DataSet 29

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\29.csv")
a
# Out:
#      index             SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY  \
# 0      322  NAGA MANI MIZO TRIPURA  1901  11.7  18.1   29.4  206.2  124.0
# 1      323  NAGA MANI MIZO TRIPURA  1902   4.8   0.5   36.3  297.8  215.5
# 2      324  NAGA MANI MIZO TRIPURA  1903   6.5  40.5  139.8   45.5  159.9
# 3      325  NAGA MANI MIZO TRIPURA  1904   2.3  46.9   47.5  290.3  230.5
# 4      326  NAGA MANI MIZO TRIPURA  1905   9.1  35.3  306.5  161.7  193.6
# ..     ...                     ...   ...   ...   ...    ...    ...    ...
# 110    432  NAGA MANI MIZO TRIPURA  2011  12.6   3.6   51.4   81.1  334.9
# 111    433  NAGA MANI MIZO TRIPURA  2012  24.5  10.2   20.3  243.5  163.5
# 112    434  NAGA MANI MIZO TRIPURA  2013   0.2   5.7   19.7   60.3  348.9
# 113    435  NAGA MANI MIZO TRIPURA  2014   1.2  21.0   25.4   49.6  192.5
# 114    436  NAGA MANI MIZO TRIPURA  2015  14.4  14.2   21.6  253.5  198.3
#
#        JUN    JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.scatter(y='FEB',x='JUN',legend=None)
# Out:
# <AxesSubplot:xlabel='JUN', ylabel='FEB'>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.pie(y='SEP',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='SEP'>

# %%
a.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # DataSet 30

# %%
b=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\30.csv")
b
# Out:
#      index                         SUBDIVISION  YEAR   JAN   FEB   MAR    APR  \
# 0      437  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901  26.5  14.8  14.1   29.2
# 1      438  SUB HIMALAYAN WEST BENGAL & SIKKIM  1902   1.2   0.7  87.1  126.1
# 2      439  SUB HIMALAYAN WEST BENGAL & SIKKIM  1903   5.5   8.7  19.6   18.6
# 3      440  SUB HIMALAYAN WEST BENGAL & SIKKIM  1904   3.4  29.2   0.9  124.3
# 4      441  SUB HIMALAYAN WEST BENGAL & SIKKIM  1905  12.0  31.2  51.9  104.4
# ..     ...                                 ...   ...   ...   ...   ...    ...
# 110    547  SUB HIMALAYAN WEST BENGAL & SIKKIM  2011   8.5  19.9  71.2  135.0
# 111    548  SUB HIMALAYAN WEST BENGAL & SIKKIM  2012  15.3  13.9  45.5  159.8
# 112    549  SUB HIMALAYAN WEST BENGAL & SIKKIM  2013   3.0  23.6  32.1  114.7
# 113    550  SUB HIMALAYAN WEST BENGAL & SIKKIM  2014   0.2  26.6  37.7   47.9
# 114    551  SUB HIMALAYAN WEST BENGAL & SIKKIM  2015  15.7  15.0  64.8  149.0
#
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.pie(y='DEC',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='DEC'>
