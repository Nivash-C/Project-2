# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DataSet 31

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\31.csv")
a
# Out:
#      index           SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY    JUN  \
# 0      552  GANGETIC WEST BENGAL  1901  37.1  58.4   3.9   64.1  121.7  198.0
# 1      553  GANGETIC WEST BENGAL  1902   0.0   1.2  44.2  103.8  161.6  140.9
# 2      554  GANGETIC WEST BENGAL  1903  17.5  24.6  37.3   30.6   78.5  201.7
# 3      555  GANGETIC WEST BENGAL  1904   0.1  23.9  35.6   17.5  160.2  286.7
# 4      556  GANGETIC WEST BENGAL  1905  30.9  49.6  84.7   84.9  156.8   70.9
# ..     ...                   ...   ...   ...   ...   ...    ...    ...    ...
# 110    662  GANGETIC WEST BENGAL  2011   2.5   2.7  40.5   75.0  132.6  434.5
# 111    663  GANGETIC WEST BENGAL  2012  40.7  15.3   4.4   57.7   44.2  146.6
# 112    664  GANGETIC WEST BENGAL  2013   2.5  10.0   4.8   45.6  195.9  233.4
# 113    665  GANGETIC WEST BENGAL  2014   0.9  42.2  19.9    1.9  124.4  193.6
# 114    666  GANGETIC WEST BENGAL  2015  12.9   5.5  19.3   88.7   57.6  247.2
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a.plot.pie(y='NOV',figsize=(7,7),labels=None,legend=None)
# Out:
# <AxesSubplot:ylabel='NOV'>

# %% [markdown]
# # DataSet 32

# %%
b=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\32.csv")
b
# Out:
#      index SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY    JUN    JUL  \
# 0      667      ORISSA  1901  39.5  65.1  16.1   51.6   79.0   78.2  288.4
# 1      668      ORISSA  1902   3.4   0.2  14.2  101.1   56.7  108.3  437.4
# 2      669      ORISSA  1903  19.7  18.9  10.5   34.6   73.3  154.3  410.4
# 3      670      ORISSA  1904   0.2  12.2  20.6   10.1  100.2  342.9  336.7
# 4      671      ORISSA  1905  24.3  17.2  66.3   56.9  107.5   92.0  330.1
# ..     ...         ...   ...   ...   ...   ...    ...    ...    ...    ...
# 110    777      ORISSA  2011   3.7  16.2   4.9   58.2   75.6  210.1  199.6
# 111    778      ORISSA  2012  50.8   3.6   0.9   34.8   21.3  169.6  324.3
# 112    779      ORISSA  2013   3.3   7.8   2.1   53.6   57.7  272.6  380.0
# 113    780      ORISSA  2014   0.0  17.6  25.1   11.7  111.9   92.2  496.2
# 114    781      ORISSA  2015  15.1   3.3  10.5   67.6   32.6  238.6  294.8
#
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.scatter(y='YEAR',x='OCT',legend=None)
# Out:
# <AxesSubplot:xlabel='OCT', ylabel='YEAR'>

# %%
b.plot.pie(y='JAN',legend=None,labels=None,figsize=(6.5,6.5),)
# Out:
# <AxesSubplot:ylabel='JAN'>

# %% [markdown]
# # DataSet 33

# %%
b=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\33.csv")
b
# Out:
#      index SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL  \
# 0      782   JHARKHAND  1901  92.7  66.6  11.1  18.4   33.5   70.9  269.4
# 1      783   JHARKHAND  1902   4.2   7.7  13.2  28.5   59.8   89.9  456.1
# 2      784   JHARKHAND  1903  25.1  19.5  10.7  32.8   56.4  142.1  206.1
# 3      785   JHARKHAND  1904   2.5  17.0  38.1   9.1  116.1  308.9  494.1
# 4      786   JHARKHAND  1905  38.4  53.3  61.6  32.9   66.2   41.5  420.3
# ..     ...         ...   ...   ...   ...   ...   ...    ...    ...    ...
# 110    892   JHARKHAND  2011   3.3   2.5   6.4  25.4   55.0  349.0  181.8
# 111    893   JHARKHAND  2012  34.6  10.3   1.5   9.6    6.6  121.1  287.2
# 112    894   JHARKHAND  2013   1.1  17.9   1.6  22.3   85.0  181.5  211.1
# 113    895   JHARKHAND  2014   9.9  47.5  22.9   1.9   98.2  139.7  321.3
# 114    896   JHARKHAND  2015  12.2   2.6  21.6  55.5   25.5  183.3  429.7
#
#        AUG    SEP    OCT   NOV  DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
b.plot.pie(y='JUL',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='JUL'>

# %% [markdown]
# # DataSet 34

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\34.csv")
a
# Out:
#      index SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL  \
# 0      897       BIHAR  1901  51.8  19.6  11.9   1.1   65.6   66.3  245.9
# 1      898       BIHAR  1902   4.6   0.7  24.3  17.3   66.3  118.2  361.0
# 2      899       BIHAR  1903   5.3   4.7   2.0   4.7   28.2  192.9  115.0
# 3      900       BIHAR  1904   6.3   1.7   3.5   5.3  118.7  191.6  394.4
# 4      901       BIHAR  1905  16.0  30.1  32.6  21.4   77.5   50.5  409.1
# ..     ...         ...   ...   ...   ...   ...   ...    ...    ...    ...
# 110   1007       BIHAR  2011   4.2   7.7   9.2  23.9   74.5  211.0  241.1
# 111   1008       BIHAR  2012  18.1   2.7   7.3  20.4   18.8   96.2  354.0
# 112   1009       BIHAR  2013   5.1  22.6   0.6  32.3   89.5  183.3  182.0
# 113   1010       BIHAR  2014  17.0  33.5   8.4   0.7  103.9  115.2  265.4
# 114   1011       BIHAR  2015  12.8   1.8  27.2  38.7   39.5  122.1  231.5
#
#        AUG    SEP    OCT   NOV  DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.pie(y='APR',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='APR'>

# %% [markdown]
# # DataSet 35

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\35.csv")
a
# Out:
#      index         SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN  \
# 0     1012  EAST UTTAR PRADESH  1901  62.6  31.3   8.2   1.1  13.6   21.8
# 1     1013  EAST UTTAR PRADESH  1902   6.1   2.3   2.4   2.0  21.4   32.5
# 2     1014  EAST UTTAR PRADESH  1903   8.2   0.4   1.3   0.7  15.3   71.6
# 3     1015  EAST UTTAR PRADESH  1904   7.3   1.5   8.3   0.4  28.7  148.0
# 4     1016  EAST UTTAR PRADESH  1905  16.8  23.6  20.0   5.4  15.4   17.3
# ..     ...                 ...   ...   ...   ...   ...   ...   ...    ...
# 110   1122  EAST UTTAR PRADESH  2011   1.0   2.7   1.6   2.9  32.2  163.8
# 111   1123  EAST UTTAR PRADESH  2012  20.3   1.2   3.4   2.8   0.2   18.5
# 112   1124  EAST UTTAR PRADESH  2013   6.1  59.6   2.7   8.7   1.1  309.7
# 113   1125  EAST UTTAR PRADESH  2014  47.4  25.8  15.4   1.7  10.7   47.8
# 114   1126  EAST UTTAR PRADESH  2015  30.0   4.1  48.2  23.2   8.6   95.3
#
#        JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
a.plot.scatter(y='MAR',x='SEP',legend=None)
# Out:
# <AxesSubplot:xlabel='SEP', ylabel='MAR'>

# %%
a.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
a.plot.pie(y='DEC',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='DEC'>

# %%
a.plot.hist(legend=None)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # DataSet 36

# %%
b=pd.read_csv(r"E:\Python Data Science\Documents\RainFall\New\36.csv")
b
# Out:
#      index  SUBDIVISION  YEAR    JAN    FEB    MAR   APR   MAY    JUN    JUL  \
# 0     1242  UTTARAKHAND  1901  134.5   81.4   44.5   5.9  60.8   33.6  381.1
# 1     1243  UTTARAKHAND  1902    0.0   17.0   52.2  63.7  52.1  113.1  444.1
# 2     1244  UTTARAKHAND  1903   68.0    7.9   87.6  10.3  37.5   83.0  251.6
# 3     1245  UTTARAKHAND  1904   40.0    5.2   78.3  13.6  61.1  180.1  449.6
# 4     1246  UTTARAKHAND  1905  115.4   80.7   99.8  26.1  70.3  111.5  299.9
# ..     ...          ...   ...    ...    ...    ...   ...   ...    ...    ...
# 110   1352  UTTARAKHAND  2011   30.9   65.2   18.0  30.9  84.2  223.1  433.3
# 111   1353  UTTARAKHAND  2012   38.8   11.9   28.1  39.2   9.1   46.0  387.1
# 112   1354  UTTARAKHAND  2013   73.0  188.3   22.0  24.7  18.2  488.9  413.4
# 113   1355  UTTARAKHAND  2014   45.9   99.9   68.4  37.6  52.9   62.9  462.7
# 114   1356  UTTARAKHAND  2015   54.5   62.6  127.3  57.3  38.0  186.6  337.0
#
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        115 non-null    int64
#  1   SUBDIVISION  115 non-null    object
#  2   YEAR         115 non-null    int64
#  3   JAN          115 non-null    float64
#  4   FEB          115 non-null    float64
#  5   MAR          115 non-null    float64
#  6   APR          115 non-null    float64
#  7   MAY          115 non-null    float64
#  8   JUN          115 non-null    float64
#  9   JUL          115 non-null    float64
#  10  AUG          115 non-null    float64
#  11  SEP          115 non-null    float64
#  12  OCT          115 non-null    float64
#  13  NOV          115 non-null    float64
#  14  DEC          115 non-null    float64
#  15  ANNUAL       115 non-null    float64
#  16  Jan-Feb      115 non-null    float64
#  17  Mar-May      115 non-null    float64
# ...

# %%
b.plot.line(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.bar(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.area(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.box(legend=None)
# Out:
# <AxesSubplot:>

# %%
b.plot.pie(y='SEP',legend=None,labels=None,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='SEP'>
